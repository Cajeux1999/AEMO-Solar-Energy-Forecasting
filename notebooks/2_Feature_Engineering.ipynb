# %%
# !git clone https://github.com/Cajeux1999/AEMO-Solar-Energy-Forecasting.git -q

# %%
# !pip install tsfresh
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from tsfresh.utilities.dataframe_functions import roll_time_series
from tsfresh.feature_extraction import EfficientFCParameters
from tsfresh import extract_features

REPO_NAME = "AEMO-Solar-Energy-Forecasting"
# %cd {REPO_NAME}
# Out:
# Requirement already satisfied: tsfresh in /usr/local/lib/python3.12/dist-packages (0.21.1)
# Requirement already satisfied: requests>=2.9.1 in /usr/local/lib/python3.12/dist-packages (from tsfresh) (2.32.4)
# Requirement already satisfied: numpy>=1.15.1 in /usr/local/lib/python3.12/dist-packages (from tsfresh) (2.0.2)
# Requirement already satisfied: pandas>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from tsfresh) (2.2.2)
# Requirement already satisfied: statsmodels>=0.13 in /usr/local/lib/python3.12/dist-packages (from tsfresh) (0.14.6)
# Requirement already satisfied: patsy>=0.4.1 in /usr/local/lib/python3.12/dist-packages (from tsfresh) (1.0.2)
# Requirement already satisfied: pywavelets in /usr/local/lib/python3.12/dist-packages (from tsfresh) (1.9.0)
# Requirement already satisfied: scikit-learn>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from tsfresh) (1.6.1)
# Requirement already satisfied: tqdm>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from tsfresh) (4.67.1)
# Requirement already satisfied: stumpy>=1.7.2 in /usr/local/lib/python3.12/dist-packages (from tsfresh) (1.13.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.12/dist-packages (from tsfresh) (3.1.2)
# Requirement already satisfied: scipy>=1.14.0 in /usr/local/lib/python3.12/dist-packages (from tsfresh) (1.16.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.25.0->tsfresh) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.25.0->tsfresh) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.25.0->tsfresh) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.9.1->tsfresh) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.9.1->tsfresh) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.9.1->tsfresh) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.9.1->tsfresh) (2025.11.12)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.22.0->tsfresh) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.22.0->tsfresh) (3.6.0)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.12/dist-packages (from statsmodels>=0.13->tsfresh) (25.0)
# Requirement already satisfied: numba>=0.57.1 in /usr/local/lib/python3.12/dist-packages (from stumpy>=1.7.2->tsfresh) (0.60.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.57.1->stumpy>=1.7.2->tsfresh) (0.43.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=0.25.0->tsfresh) (1.17.0)
# /content/AEMO-Solar-Energy-Forecasting

# %%
#Importing the train_size defined in the config.py file, to generate the EDA study based on the training dataset
from src import config, utils

train_size = config.TRAIN_SIZE

#Defining the filepath to load the dataset
filepath = '/content/AEMO-Solar-Energy-Forecasting/data/raw/'

# %%
#Importing New South Wales power output series
nsw1_solar = pd.read_csv(filepath+'nsw_solar.csv').drop(columns=['Unnamed: 0'])
nsw1_solar["ds"] = pd.to_datetime(nsw1_solar["ds"]).dt.tz_localize(None)

# %% [markdown]
# ## TSFresh

# %%
# Create a rolling dataset to then extract TSFresh Features.
df_rolled = roll_time_series(nsw1_solar, column_id="unique_id", column_sort="ds")
# Out:
# Rolling: 100%|██████████| 20/20 [00:32<00:00,  1.62s/it]

# %%
df_rolled.head(10)
# Out:
#                    ds         y unique_id                           id
# 0 2024-07-01 00:00:00  0.041056      NSW1  (NSW1, 2024-07-01 00:00:00)
# 1 2024-07-01 00:00:00  0.041056      NSW1  (NSW1, 2024-07-01 00:30:00)
# 2 2024-07-01 00:30:00  0.041056      NSW1  (NSW1, 2024-07-01 00:30:00)
# 3 2024-07-01 00:00:00  0.041056      NSW1  (NSW1, 2024-07-01 01:00:00)
# 4 2024-07-01 00:30:00  0.041056      NSW1  (NSW1, 2024-07-01 01:00:00)
# 5 2024-07-01 01:00:00  0.041056      NSW1  (NSW1, 2024-07-01 01:00:00)
# 6 2024-07-01 00:00:00  0.041056      NSW1  (NSW1, 2024-07-01 01:30:00)
# 7 2024-07-01 00:30:00  0.041056      NSW1  (NSW1, 2024-07-01 01:30:00)
# 8 2024-07-01 01:00:00  0.041056      NSW1  (NSW1, 2024-07-01 01:30:00)
# 9 2024-07-01 01:30:00  0.041056      NSW1  (NSW1, 2024-07-01 01:30:00)

# %%
df_rolled.drop(columns='unique_id',inplace=True)

#Actual feature generation with TSFresh for a rolled time-series format.
settings = EfficientFCParameters()
df_features = extract_features(df_rolled, column_id="id", column_sort="ds", default_fc_parameters=settings)

# %%
# The extract_features method generated more than 700 different features.
df_features.tail(5)
# Out:
#      unique_id                   ds  \
# 8780      NSW1  2024-12-30 22:00:00
# 8781      NSW1  2024-12-30 22:30:00
# 8782      NSW1  2024-12-30 23:00:00
# 8783      NSW1  2024-12-30 23:30:00
# 8784      NSW1  2024-12-31 00:00:00
#
#       y__variance_larger_than_standard_deviation  y__has_duplicate_max  \
# 8780                                         1.0                   0.0
# 8781                                         1.0                   0.0
# 8782                                         1.0                   0.0
# 8783                                         1.0                   0.0
# 8784                                         1.0                   0.0
#
#       y__has_duplicate_min  y__has_duplicate  y__sum_values  y__abs_energy  \
# 8780                   1.0               1.0   7.266493e+06   1.521749e+10
# 8781                   1.0               1.0   7.266493e+06   1.521749e+10
# 8782                   1.0               1.0   7.266493e+06   1.521749e+10
# 8783                   1.0               1.0   7.266493e+06   1.521749e+10
# 8784                   1.0               1.0   7.266493e+06   1.521749e+10
#
#       y__mean_abs_change  y__mean_change  ...  y__fourier_entropy__bins_5  \
# 8780          119.941864        0.000002  ...                    0.090729
# 8781          119.928205        0.000002  ...                    0.090729
# 8782          119.914549        0.000002  ...                    0.090729
# 8783          119.900896        0.000002  ...                    0.090729
# 8784          119.887246        0.000002  ...                    0.090729
#
#       y__fourier_entropy__bins_10  y__fourier_entropy__bins_100  \
# 8780                     0.090729                        0.6134
# 8781                     0.090729                        0.6134
# 8782                     0.090729                        0.6134
# 8783                     0.090729                        0.6134
# 8784                     0.090729                        0.6134
#
#       y__permutation_entropy__dimension_3__tau_1  \
# 8780                                    1.151429
# 8781                                    1.151354
# 8782                                    1.151278
# 8783                                    1.151202
# 8784                                    1.151127
#
#       y__permutation_entropy__dimension_4__tau_1  \
# 8780                                    1.691774
# 8781                                    1.691647
# 8782                                    1.691519
# 8783                                    1.691392
# 8784                                    1.691265
#
#       y__permutation_entropy__dimension_5__tau_1  \
# 8780                                    2.335228
# 8781                                    2.335036
# 8782                                    2.334843
# 8783                                    2.334650
# 8784                                    2.334457
#
#       y__permutation_entropy__dimension_6__tau_1  \
# 8780                                    2.905612
# 8781                                    2.905713
# 8782                                    2.905462
# 8783                                    2.905211
# 8784                                    2.904960
#
#       y__permutation_entropy__dimension_7__tau_1  \
# 8780                                    3.427962
# 8781                                    3.428010
# 8782                                    3.428056
# 8783                                    3.427751
# 8784                                    3.427447
#
#       y__query_similarity_count__query_None__threshold_0.0  \
# 8780                                                NaN
# 8781                                                NaN
# 8782                                                NaN
# 8783                                                NaN
# 8784                                                NaN
#
#       y__mean_n_absolute_max__number_of_maxima_7
# 8780                                 3387.983149
# 8781                                 3387.983149
# 8782                                 3387.983149
# 8783                                 3387.983149
# 8784                                 3387.983149
#
# [5 rows x 779 columns]

# %%
#Importing exogenous variables for New South Wales
exog = pd.read_csv(filepath+'solar_exogenous.csv')
exog["ds"] = pd.to_datetime(exog["period_end"]).dt.tz_localize(None)
exog.drop(columns=['period','period_end'],inplace=True)

# %%
# Adding to the feature dataset the exogenous features (air_temp, dni, ghi)
df_features['ds'] = pd.to_datetime(df_features['ds'])
exog['ds'] = pd.to_datetime(exog['ds'])

df_features = pd.merge(df_features, exog, on='ds', how='left')

# %%
# Adding cyclical features to the dataset, to represent time
df_features = utils.add_cyclical_features(df_features)

# %%
# Final dataset with created features
df_features.tail(5)
# Out:
#      unique_id                  ds  \
# 8780      NSW1 2024-12-30 22:00:00
# 8781      NSW1 2024-12-30 22:30:00
# 8782      NSW1 2024-12-30 23:00:00
# 8783      NSW1 2024-12-30 23:30:00
# 8784      NSW1 2024-12-31 00:00:00
#
#       y__variance_larger_than_standard_deviation  y__has_duplicate_max  \
# 8780                                         1.0                   0.0
# 8781                                         1.0                   0.0
# 8782                                         1.0                   0.0
# 8783                                         1.0                   0.0
# 8784                                         1.0                   0.0
#
#       y__has_duplicate_min  y__has_duplicate  y__sum_values  y__abs_energy  \
# 8780                   1.0               1.0   7.266493e+06   1.521749e+10
# 8781                   1.0               1.0   7.266493e+06   1.521749e+10
# 8782                   1.0               1.0   7.266493e+06   1.521749e+10
# 8783                   1.0               1.0   7.266493e+06   1.521749e+10
# 8784                   1.0               1.0   7.266493e+06   1.521749e+10
#
#       y__mean_abs_change  y__mean_change  ...  \
# 8780          119.941864        0.000002  ...
# 8781          119.928205        0.000002  ...
# 8782          119.914549        0.000002  ...
# 8783          119.900896        0.000002  ...
# 8784          119.887246        0.000002  ...
#
#       y__mean_n_absolute_max__number_of_maxima_7  air_temp  dni  ghi  \
# 8780                                 3387.983149        24    0    0
# 8781                                 3387.983149        24    0    0
# 8782                                 3387.983149        23    0    0
# 8783                                 3387.983149        23    0    0
# 8784                                 3387.983149        23    0    0
#
#       halfhour_sin  halfhour_cos       day_sin  day_cos     month_sin  \
# 8780     -0.500000      0.866025 -2.012985e-01  0.97953 -2.449294e-16
# 8781     -0.382683      0.923880 -2.012985e-01  0.97953 -2.449294e-16
# 8782     -0.258819      0.965926 -2.012985e-01  0.97953 -2.449294e-16
# 8783     -0.130526      0.991445 -2.012985e-01  0.97953 -2.449294e-16
# 8784      0.000000      1.000000 -2.449294e-16  1.00000 -2.449294e-16
#
#       month_cos
# 8780        1.0
# 8781        1.0
# 8782        1.0
# 8783        1.0
# 8784        1.0
#
# [5 rows x 788 columns]

# %%
df_features.dtypes.value_counts()
# Out:
# float64           783
# int64               3
# datetime64[ns]      1
# object              1
# Name: count, dtype: int64

# %% [markdown]
# ## Preprocessing of Feature Selection

# %%
# !pip install arfs
import arfs
import arfs.preprocessing as arfspp
from arfs.preprocessing import dtype_column_selector, OrdinalEncoderPandas
import arfs.feature_selection as arfsfs
from sklearn.pipeline import Pipeline
# Out:
# Collecting arfs
#   Downloading arfs-3.0.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: lightgbm>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from arfs) (4.6.0)
# Requirement already satisfied: matplotlib>=3.9.4 in /usr/local/lib/python3.12/dist-packages (from arfs) (3.10.0)
# Requirement already satisfied: numpy>=2.0.2 in /usr/local/lib/python3.12/dist-packages (from arfs) (2.0.2)
# Collecting pandas>=2.2.3 (from arfs)
#   Downloading pandas-2.3.3-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (91 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.2/91.2 kB 6.1 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn>=1.6.1 in /usr/local/lib/python3.12/dist-packages (from arfs) (1.6.1)
# Requirement already satisfied: scipy>=1.13.1 in /usr/local/lib/python3.12/dist-packages (from arfs) (1.16.3)
# Requirement already satisfied: seaborn>=0.13.2 in /usr/local/lib/python3.12/dist-packages (from arfs) (0.13.2)
# Requirement already satisfied: shap>=0.47.0 in /usr/local/lib/python3.12/dist-packages (from arfs) (0.50.0)
# Requirement already satisfied: statsmodels>=0.14.4 in /usr/local/lib/python3.12/dist-packages (from arfs) (0.14.6)
# Requirement already satisfied: tqdm>=4.67.1 in /usr/local/lib/python3.12/dist-packages (from arfs) (4.67.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9.4->arfs) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9.4->arfs) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9.4->arfs) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9.4->arfs) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9.4->arfs) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9.4->arfs) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9.4->arfs) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9.4->arfs) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2.3->arfs) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2.3->arfs) (2025.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.6.1->arfs) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.6.1->arfs) (3.6.0)
# Requirement already satisfied: slicer==0.0.8 in /usr/local/lib/python3.12/dist-packages (from shap>=0.47.0->arfs) (0.0.8)
# Requirement already satisfied: numba>=0.54 in /usr/local/lib/python3.12/dist-packages (from shap>=0.47.0->arfs) (0.60.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.12/dist-packages (from shap>=0.47.0->arfs) (3.1.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from shap>=0.47.0->arfs) (4.15.0)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.12/dist-packages (from statsmodels>=0.14.4->arfs) (1.0.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.54->shap>=0.47.0->arfs) (0.43.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.9.4->arfs) (1.17.0)
# Downloading arfs-3.0.0-py3-none-any.whl (776 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 776.9/776.9 kB 14.9 MB/s eta 0:00:00
# Downloading pandas-2.3.3-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (12.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 37.1 MB/s eta 0:00:00
# Installing collected packages: pandas, arfs
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.3.3 which is incompatible.
# Successfully installed arfs-3.0.0 pandas-2.3.3

# %%
'''
Basic feature selection to filter columns:
1. with more than 5% missing values
2. high cardinality
3. high collinearity
4. zero variance
'''
basic_fs_pipeline = Pipeline(
    [
        ("missing", arfsfs.MissingValueThreshold(threshold=0.05)),
        ("unique", arfsfs.UniqueValuesThreshold(threshold=1)),
        ("cardinality", arfsfs.CardinalityThreshold(threshold=10)),
        ("collinearity", arfsfs.CollinearityThreshold(threshold=0.75)),
    ]
)

# %%
X = basic_fs_pipeline.fit_transform(df_features)
# Out:
# /usr/local/lib/python3.12/dist-packages/arfs/association.py:802: RuntimeWarning: invalid value encountered in scalar divide
#   return wcov(x, y, w) / np.sqrt(wcov(x, x, w) * wcov(y, y, w))

# %%
# the preprocessing method filtered from 788 columns to 520 features.
X.tail(5)
# Out:
#                       ds  y__variance_larger_than_standard_deviation  \
# 8780 2024-12-30 22:00:00                                         1.0
# 8781 2024-12-30 22:30:00                                         1.0
# 8782 2024-12-30 23:00:00                                         1.0
# 8783 2024-12-30 23:30:00                                         1.0
# 8784 2024-12-31 00:00:00                                         1.0
#
#       y__has_duplicate_max  y__has_duplicate_min  y__has_duplicate  \
# 8780                   0.0                   1.0               1.0
# 8781                   0.0                   1.0               1.0
# 8782                   0.0                   1.0               1.0
# 8783                   0.0                   1.0               1.0
# 8784                   0.0                   1.0               1.0
#
#       y__mean_second_derivative_central  y__last_location_of_maximum  \
# 8780                                0.0                     0.943059
# 8781                                0.0                     0.942951
# 8782                                0.0                     0.942844
# 8783                                0.0                     0.942737
# 8784                                0.0                     0.942629
#
#       y__last_location_of_minimum  y__minimum  y__symmetry_looking__r_0.1  \
# 8780                     0.913905    0.003056                         0.0
# 8781                     0.913801    0.003056                         0.0
# 8782                     0.913697    0.003056                         0.0
# 8783                     0.913593    0.003056                         0.0
# 8784                     0.913489    0.003056                         0.0
#
#       ...  y__ratio_beyond_r_sigma__r_1  y__ratio_beyond_r_sigma__r_2  \
# 8780  ...                      0.227537                      0.034734
# 8781  ...                      0.227511                      0.034730
# 8782  ...                      0.227485                      0.034726
# 8783  ...                      0.227459                      0.034722
# 8784  ...                      0.227433                      0.034718
#
#       y__ratio_beyond_r_sigma__r_3  y__fourier_entropy__bins_2  \
# 8780                           0.0                    0.079983
# 8781                           0.0                    0.079983
# 8782                           0.0                    0.079983
# 8783                           0.0                    0.079983
# 8784                           0.0                    0.079983
#
#       y__fourier_entropy__bins_3  air_temp  halfhour_sin  halfhour_cos  \
# 8780                    0.090729        24     -0.500000      0.866025
# 8781                    0.090729        24     -0.382683      0.923880
# 8782                    0.090729        23     -0.258819      0.965926
# 8783                    0.090729        23     -0.130526      0.991445
# 8784                    0.090729        23      0.000000      1.000000
#
#            day_sin  day_cos
# 8780 -2.012985e-01  0.97953
# 8781 -2.012985e-01  0.97953
# 8782 -2.012985e-01  0.97953
# 8783 -2.012985e-01  0.97953
# 8784 -2.449294e-16  1.00000
#
# [5 rows x 520 columns]

# %%
X.to_csv('/content/AEMO-Solar-Energy-Forecasting/data/df_features_preprocessed.csv')
